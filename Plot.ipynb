# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
c1df = pd.read_excel("./tests/impact_c1_iris_res.xlsx",index_col="C1")
c1df
# Out:
#      Gbest score
# C1
# 0.0     0.196187
# 0.1     0.195244
# 0.2     0.195244
# 0.3     0.195244
# 0.4     0.219242
# 0.5     0.196187
# 0.6     0.189894
# 0.7     0.195244
# 0.8     0.196187
# 0.9     0.195244
# 1.0     0.195244
# 1.1     0.195244
# 1.2     0.195244
# 1.3     0.196187
# 1.4     0.195244
# 1.5     0.196187
# 1.6     0.195244
# 1.7     0.196187
# 1.8     0.204981
# 1.9     0.196187

# %%
plt.figure()
c1df.plot(kind="line")
# Out:
# <AxesSubplot:xlabel='C1'>

# %%
c2df = pd.read_excel("./tests/impact_c2_iris_res.xlsx",index_col="C2")
plt.figure()
c2df.plot(kind="line")
# Out:
# <AxesSubplot:xlabel='C2'>

# %%
ddf = pd.read_excel("./tests/impact_dumpw_iris_res.xlsx",index_col="decw")
plt.figure()
ddf.plot(kind="line")
# Out:
# <AxesSubplot:xlabel='decw'>

# %%
pdf = pd.read_excel("./tests/impact_particles_iris_res.xlsx",index_col="particles")
plt.figure()
pdf.plot(kind="line")
# Out:
# <AxesSubplot:xlabel='particles'>

# %%
iterdf = pd.read_excel("./tests/impact_iter_iris_res.xlsx",index_col="iter")
plt.figure()
iterdf.plot(kind="line")
# Out:
# <AxesSubplot:xlabel='iter'>

# %%
testdf = pd.read_excel("./tests/impact_best_iris_res.xlsx",index_col="test")
plt.figure()
testdf.plot(kind="line")
# Out:
# <AxesSubplot:xlabel='test'>
